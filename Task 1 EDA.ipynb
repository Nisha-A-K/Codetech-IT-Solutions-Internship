# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('apartment.csv', encoding='latin1', low_memory=False ,delimiter=';')

# %%
data.head()
# Out:
#            id                category                            title  \
# 0  5668640009  housing/rent/apartment       One BR 507 & 509 Esplanade
# 1  5668639818  housing/rent/apartment      Three BR 146 Lochview Drive
# 2  5668639686  housing/rent/apartment  Three BR 3101 Morningside Drive
# 3  5668639659  housing/rent/apartment            Two BR 209 Aegean Way
# 4  5668639374  housing/rent/apartment         One BR 4805 Marquette NE
#
#                                                 body amenities  bathrooms  \
# 0  This unit is located at 507 & 509 Esplanade, R...       NaN        1.0
# 1  This unit is located at 146 Lochview Drive, Ne...       NaN        1.5
# 2  This unit is located at 3101 Morningside Drive...       NaN        2.0
# 3  This unit is located at 209 Aegean Way, Vacavi...       NaN        1.0
# 4  This unit is located at 4805 Marquette NE, Alb...       NaN        1.0
#
#    bedrooms currency fee  has_photo  ... price_display  price_type  \
# ...

# %%
df = pd.DataFrame(data )

# %%
df.head()
# Out:
#            id                category                            title  \
# 0  5668640009  housing/rent/apartment       One BR 507 & 509 Esplanade
# 1  5668639818  housing/rent/apartment      Three BR 146 Lochview Drive
# 2  5668639686  housing/rent/apartment  Three BR 3101 Morningside Drive
# 3  5668639659  housing/rent/apartment            Two BR 209 Aegean Way
# 4  5668639374  housing/rent/apartment         One BR 4805 Marquette NE
#
#                                                 body amenities  bathrooms  \
# 0  This unit is located at 507 & 509 Esplanade, R...       NaN        1.0
# 1  This unit is located at 146 Lochview Drive, Ne...       NaN        1.5
# 2  This unit is located at 3101 Morningside Drive...       NaN        2.0
# 3  This unit is located at 209 Aegean Way, Vacavi...       NaN        1.0
# 4  This unit is located at 4805 Marquette NE, Alb...       NaN        1.0
#
#    bedrooms currency fee  has_photo  ... price_display  price_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             99492 non-null  int64
#  1   category       99492 non-null  object
#  2   title          99492 non-null  object
#  3   body           99492 non-null  object
#  4   amenities      83448 non-null  object
#  5   bathrooms      99429 non-null  float64
#  6   bedrooms       99368 non-null  float64
#  7   currency       99492 non-null  object
#  8   fee            99492 non-null  object
#  9   has_photo      99492 non-null  object
#  10  pets_allowed   39068 non-null  object
#  11  price          99491 non-null  float64
#  12  price_display  99491 non-null  object
#  13  price_type     99492 non-null  object
#  14  square_feet    99492 non-null  int64
#  15  address        7943 non-null   object
#  16  cityname       99190 non-null  object
# ...

# %%
df.shape
# Out:
# (99492, 22)

# %%
df.isnull().sum()
# Out:
# id                   0
# category             0
# title                0
# body                 0
# amenities        16044
# bathrooms           63
# bedrooms           124
# currency             0
# fee                  0
# has_photo            0
# pets_allowed     60424
# price                1
# price_display        1
# price_type           0
# square_feet          0
# address          91549
# cityname           302
# state              302
# latitude            25
# longitude           25
# source               0
# time                 0
# dtype: int64

# %%
dfc = df.copy()

# %%
dfc.head()
# Out:
#            id                category                            title  \
# 0  5668640009  housing/rent/apartment       One BR 507 & 509 Esplanade
# 1  5668639818  housing/rent/apartment      Three BR 146 Lochview Drive
# 2  5668639686  housing/rent/apartment  Three BR 3101 Morningside Drive
# 3  5668639659  housing/rent/apartment            Two BR 209 Aegean Way
# 4  5668639374  housing/rent/apartment         One BR 4805 Marquette NE
#
#                                                 body amenities  bathrooms  \
# 0  This unit is located at 507 & 509 Esplanade, R...       NaN        1.0
# 1  This unit is located at 146 Lochview Drive, Ne...       NaN        1.5
# 2  This unit is located at 3101 Morningside Drive...       NaN        2.0
# 3  This unit is located at 209 Aegean Way, Vacavi...       NaN        1.0
# 4  This unit is located at 4805 Marquette NE, Alb...       NaN        1.0
#
#    bedrooms currency fee  has_photo  ... price_display  price_type  \
# ...

# %%
dfc.drop(['id', 'title','time'],axis= 1 ,inplace = True)

# %%
dfc.drop('address',axis= 1 ,inplace = True)

# %%
dfc.head()
# Out:
#                  category                                               body  \
# 0  housing/rent/apartment  This unit is located at 507 & 509 Esplanade, R...
# 1  housing/rent/apartment  This unit is located at 146 Lochview Drive, Ne...
# 2  housing/rent/apartment  This unit is located at 3101 Morningside Drive...
# 3  housing/rent/apartment  This unit is located at 209 Aegean Way, Vacavi...
# 4  housing/rent/apartment  This unit is located at 4805 Marquette NE, Alb...
#
#   amenities  bathrooms  bedrooms currency fee  has_photo pets_allowed   price  \
# 0       NaN        1.0       1.0      USD  No  Thumbnail         Cats  2195.0
# 1       NaN        1.5       3.0      USD  No  Thumbnail    Cats,Dogs  1250.0
# 2       NaN        2.0       3.0      USD  No  Thumbnail          NaN  1395.0
# 3       NaN        1.0       2.0      USD  No  Thumbnail    Cats,Dogs  1600.0
# 4       NaN        1.0       1.0      USD  No  Thumbnail    Cats,Dogs   975.0
#
# ...

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category       99492 non-null  object
#  1   body           99492 non-null  object
#  2   amenities      83448 non-null  object
#  3   bathrooms      99429 non-null  float64
#  4   bedrooms       99368 non-null  float64
#  5   currency       99492 non-null  object
#  6   fee            99492 non-null  object
#  7   has_photo      99492 non-null  object
#  8   pets_allowed   39068 non-null  object
#  9   price          99491 non-null  float64
#  10  price_display  99491 non-null  object
#  11  price_type     99492 non-null  object
#  12  square_feet    99492 non-null  int64
#  13  cityname       99190 non-null  object
#  14  state          99190 non-null  object
#  15  latitude       99467 non-null  float64
#  16  longitude      99467 non-null  float64
# ...

# %%
dfc.isnull().sum()
# Out:
# category             0
# body                 0
# amenities        16044
# bathrooms           63
# bedrooms           124
# currency             0
# fee                  0
# has_photo            0
# pets_allowed     60424
# price                1
# price_display        1
# price_type           0
# square_feet          0
# cityname           302
# state              302
# latitude            25
# longitude           25
# source               0
# dtype: int64

# %%
dfc.drop(['amenities','pets_allowed'],axis= 1 ,inplace = True)

# %%
dfc.drop(['price_display'],axis= 1 ,inplace = True)

# %%
dfc.drop('has_photo',axis= 1 ,inplace = True)

# %%
dfc.drop('body',axis= 1 ,inplace = True)

# %%
dfc.head()
# Out:
#                  category  bathrooms  bedrooms currency fee   price  \
# 0  housing/rent/apartment        1.0       1.0      USD  No  2195.0
# 1  housing/rent/apartment        1.5       3.0      USD  No  1250.0
# 2  housing/rent/apartment        2.0       3.0      USD  No  1395.0
# 3  housing/rent/apartment        1.0       2.0      USD  No  1600.0
# 4  housing/rent/apartment        1.0       1.0      USD  No   975.0
#
#   price_type  square_feet       cityname state  latitude  longitude     source
# 0    Monthly          542  Redondo Beach    CA   33.8520  -118.3759  RentLingo
# 1    Monthly         1500   Newport News    VA   37.0867   -76.4941  RentLingo
# 2    Monthly         1650        Raleigh    NC   35.8230   -78.6438  RentLingo
# 3    Monthly          820      Vacaville    CA   38.3622  -121.9712  RentLingo
# 4    Monthly          624    Albuquerque    NM   35.1038  -106.6110  RentLingo

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category     99492 non-null  object
#  1   bathrooms    99429 non-null  float64
#  2   bedrooms     99368 non-null  float64
#  3   currency     99492 non-null  object
#  4   fee          99492 non-null  object
#  5   price        99491 non-null  float64
#  6   price_type   99492 non-null  object
#  7   square_feet  99492 non-null  int64
#  8   cityname     99190 non-null  object
#  9   state        99190 non-null  object
#  10  latitude     99467 non-null  float64
#  11  longitude    99467 non-null  float64
#  12  source       99492 non-null  object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 9.9+ MB

# %%
dfc.isna().sum()
# Out:
# category         0
# bathrooms       63
# bedrooms       124
# currency         0
# fee              0
# price            1
# price_type       0
# square_feet      0
# cityname       302
# state          302
# latitude        25
# longitude       25
# source           0
# dtype: int64

# %%
dfc.describe().T
# Out:
#                count         mean         std       min        25%        50%  \
# bathrooms    99429.0     1.445323    0.547021    1.0000     1.0000     1.0000
# bedrooms     99368.0     1.728212    0.749200    0.0000     1.0000     2.0000
# price        99491.0  1527.057281  904.245882  100.0000  1013.0000  1350.0000
# square_feet  99492.0   956.430688  417.571522  101.0000   729.0000   900.0000
# latitude     99467.0    36.947988    4.599461   19.5738    33.7465    37.2282
# longitude    99467.0   -91.568656   15.817168 -159.3698  -104.7919   -84.5623
#
#                    75%         max
# bathrooms       2.0000      9.0000
# bedrooms        2.0000      9.0000
# price        1795.0000  52500.0000
# square_feet  1115.0000  50000.0000
# latitude       39.9530     64.8332
# longitude     -77.6082    -68.7788

# %%
dfc['bathrooms'].fillna(dfc['bathrooms'].mean(),inplace=True)

# %%
dfc['bedrooms'].fillna(dfc['bedrooms'].mean(),inplace=True)

# %%
dfc.isna().sum()
# Out:
# category         0
# bathrooms        0
# bedrooms         0
# currency         0
# fee              0
# price            1
# price_type       0
# square_feet      0
# cityname       302
# state          302
# latitude        25
# longitude       25
# source           0
# dtype: int64

# %%
dfc['price'].fillna(dfc['price'].mode()[0],inplace=True)

# %%
dfc.isna().sum()
# Out:
# category         0
# bathrooms        0
# bedrooms         0
# currency         0
# fee              0
# price            0
# price_type       0
# square_feet      0
# cityname       302
# state          302
# latitude        25
# longitude       25
# source           0
# dtype: int64

# %%
dfc['cityname'].fillna(dfc['cityname'].mode()[0],inplace=True)
dfc['state'].fillna(dfc['state'].mode()[0],inplace=True)

# %%
dfc.isna().sum()
# Out:
# category        0
# bathrooms       0
# bedrooms        0
# currency        0
# fee             0
# price           0
# price_type      0
# square_feet     0
# cityname        0
# state           0
# latitude       25
# longitude      25
# source          0
# dtype: int64

# %%
dfc['latitude'].fillna(dfc['latitude'].mode()[0],inplace=True)
dfc['longitude'].fillna(dfc['longitude'].mode()[0],inplace=True)

# %%
dfc.isna().sum()
# Out:
# category       0
# bathrooms      0
# bedrooms       0
# currency       0
# fee            0
# price          0
# price_type     0
# square_feet    0
# cityname       0
# state          0
# latitude       0
# longitude      0
# source         0
# dtype: int64

# %%
dfc.duplicated().sum()
# Out:
# 14629

# %%
dfc.drop_duplicates(inplace = True)

# %%
dfc.duplicated().sum()
# Out:
# 0

# %%
num_cols = dfc.select_dtypes(include = 'number')

# %%
num_cols
# Out:
#        bathrooms  bedrooms   price  square_feet  latitude  longitude
# 0            1.0       1.0  2195.0          542   33.8520  -118.3759
# 1            1.5       3.0  1250.0         1500   37.0867   -76.4941
# 2            2.0       3.0  1395.0         1650   35.8230   -78.6438
# 3            1.0       2.0  1600.0          820   38.3622  -121.9712
# 4            1.0       1.0   975.0          624   35.1038  -106.6110
# ...          ...       ...     ...          ...       ...        ...
# 99486        1.0       1.0   798.0          650   30.2254   -81.7579
# 99487        1.0       1.0   780.0          605   29.6151   -95.1998
# 99489        1.0       1.0  1325.0          650   32.7379  -117.0914
# 99490        1.0       1.0   931.0          701   35.4158   -80.8451
# 99491        1.5       2.0  1595.0          900   32.7379  -117.0914
#
# [84863 rows x 6 columns]

# %%
cat_cols = dfc.select_dtypes(include = 'object')

# %%
cat_cols
# Out:
#                      category currency fee price_type       cityname state  \
# 0      housing/rent/apartment      USD  No    Monthly  Redondo Beach    CA
# 1      housing/rent/apartment      USD  No    Monthly   Newport News    VA
# 2      housing/rent/apartment      USD  No    Monthly        Raleigh    NC
# 3      housing/rent/apartment      USD  No    Monthly      Vacaville    CA
# 4      housing/rent/apartment      USD  No    Monthly    Albuquerque    NM
# ...                       ...      ...  ..        ...            ...   ...
# 99486  housing/rent/apartment      USD  No    Monthly   Jacksonville    FL
# 99487  housing/rent/apartment      USD  No    Monthly        Houston    TX
# 99489  housing/rent/apartment      USD  No    Monthly      San Diego    CA
# 99490  housing/rent/apartment      USD  No    Monthly   Huntersville    NC
# 99491  housing/rent/apartment      USD  No    Monthly      San Diego    CA
#
#              source
# 0         RentLingo
# 1         RentLingo
# ...

# %%
# 1. Unique values and their counts
unique_values = {
    col: {"unique": dfc[col].unique().tolist(), "count": len(dfc[col].unique())} for col in dfc.columns
}

# %%
print("Unique Values and Counts:\n", unique_values)
# Out:
# Unique Values and Counts:
# ...

# %%
dfc.head(15)
# Out:
#                   category  bathrooms  bedrooms currency fee   price  \
# 0   housing/rent/apartment        1.0       1.0      USD  No  2195.0
# 1   housing/rent/apartment        1.5       3.0      USD  No  1250.0
# 2   housing/rent/apartment        2.0       3.0      USD  No  1395.0
# 3   housing/rent/apartment        1.0       2.0      USD  No  1600.0
# 4   housing/rent/apartment        1.0       1.0      USD  No   975.0
# 5   housing/rent/apartment        1.5       2.0      USD  No  1250.0
# 6   housing/rent/apartment        2.0       2.0      USD  No  1600.0
# 7   housing/rent/apartment        2.0       2.0      USD  No  1300.0
# 8   housing/rent/apartment        1.0       2.0      USD  No   795.0
# 9   housing/rent/apartment        2.0       2.0      USD  No  2150.0
# 10  housing/rent/apartment        2.5       3.0      USD  No  1795.0
# 11  housing/rent/apartment        3.0       2.0      USD  No  3195.0
# 12  housing/rent/apartment        2.0       2.0      USD  No  2395.0
# ...

# %%
#dfc['bathrooms'] = dfc['bathrooms'].round().astype(int)

# %%
dfc['bathrooms']
# Out:
# 0        1.0
# 1        1.5
# 2        2.0
# 3        1.0
# 4        1.0
#         ...
# 99486    1.0
# 99487    1.0
# 99489    1.0
# 99490    1.0
# 99491    1.5
# Name: bathrooms, Length: 84863, dtype: float64

# %%
num_cols
# Out:
#        bathrooms  bedrooms   price  square_feet  latitude  longitude
# 0            1.0       1.0  2195.0          542   33.8520  -118.3759
# 1            1.5       3.0  1250.0         1500   37.0867   -76.4941
# 2            2.0       3.0  1395.0         1650   35.8230   -78.6438
# 3            1.0       2.0  1600.0          820   38.3622  -121.9712
# 4            1.0       1.0   975.0          624   35.1038  -106.6110
# ...          ...       ...     ...          ...       ...        ...
# 99486        1.0       1.0   798.0          650   30.2254   -81.7579
# 99487        1.0       1.0   780.0          605   29.6151   -95.1998
# 99489        1.0       1.0  1325.0          650   32.7379  -117.0914
# 99490        1.0       1.0   931.0          701   35.4158   -80.8451
# 99491        1.5       2.0  1595.0          900   32.7379  -117.0914
#
# [84863 rows x 6 columns]

# %%
for i in num_cols.columns:
    sns.boxplot(data = dfc, x = i)
    plt.show()

# %%
def outliers(dfc):
    for col in dfc.select_dtypes(include=['int64', 'float64']).columns:
        Q1 = dfc[col].quantile(0.25)
        Q3 = dfc[col].quantile(0.75)
        IQR = Q3 - Q1

        lower = Q1 - (1.5 * IQR)
        upper = Q3 + (1.5 * IQR)

        # Capping
        dfc[col] = dfc[col].apply(lambda x: lower if x < lower else upper if x > upper else x)

    return dfc

# %%
df1 =outliers(dfc)

# %%
for i in num_cols.columns:
    sns.boxplot(data = df1, x = i)
    plt.show()

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer(method='yeo-johnson')

# %%
numerical_features = dfc.select_dtypes(include=['float64', 'int64']).columns

# %%
dfc[numerical_features] = pt.fit_transform(df1[numerical_features])

# %%
dfc[numerical_features].skew()
# Out:
# bathrooms      0.327564
# bedrooms      -0.005735
# price         -0.001787
# square_feet    0.005334
# latitude      -0.011429
# longitude     -0.123747
# dtype: float64

# %%
dfc[numerical_features].kurtosis()
# Out:
# bathrooms     -1.812252
# bedrooms      -0.405405
# price         -0.404950
# square_feet    0.068357
# latitude      -0.199782
# longitude     -1.222770
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
le = LabelEncoder()

# %%
dfc['category'] = le.fit_transform(dfc['category'])

# %%
dfc.head()
# Out:
#    category  bathrooms  bedrooms currency fee     price price_type  \
# 0         1  -0.867047 -1.026557      USD  No  1.105110    Monthly
# 1         1   0.469071  1.618755      USD  No -0.263333    Monthly
# 2         1   1.133517  1.618755      USD  No  0.001421    Monthly
# 3         1  -0.867047  0.481493      USD  No  0.333524    Monthly
# 4         1  -0.867047 -1.026557      USD  No -0.859150    Monthly
#
#    square_feet       cityname state  latitude  longitude     source
# 0    -1.508883  Redondo Beach    CA -0.675746  -1.478306  RentLingo
# 1     1.704944   Newport News    VA  0.026150   1.021286  RentLingo
# 2     2.071585        Raleigh    NC -0.249190   0.801442  RentLingo
# 3    -0.343851      Vacaville    CA  0.305483  -1.590573  RentLingo
# 4    -1.132085    Albuquerque    NM -0.405252  -1.036931  RentLingo

# %%
df2 = df1[numerical_features]

# %%
# finding correleation
correlation = df2.corr()

# %%
plt.figure(figsize =(12,10))
sns.heatmap(correlation, annot = True, fmt='.2f', cmap = 'viridis')
plt.show()

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
x = dfc.drop('price',axis =1)
y = dfc['price']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[143], line 2
#       1 x = dfc.drop('price',axis =1)
# ----> 2 y = dfc('price')
#
# TypeError: 'DataFrame' object is not callable
